# %% [markdown]
# # markdown(포트폴리오 정리 문법)
# 주석 단축키 -- > esc + ctrl + mm

# %% [markdown]
# ## 1. 제목 (Header)

# %% [markdown]
# # 제목 1.
# ## 제목 2.
# ### 제목 3.
# #### 제목 4.
# ##### 제목 5.

# %% [markdown]
# # 2. 목록
# - 순서가 없는 목록

# %% [markdown]
# - 목록 1
# - 목록 2
# - 목록 3

# %% [markdown]
# - 목록 1
#     - 목록 1-1
#         - 목록 1-2
#             - 목록 1-3
#                 - 목록 1-4

# %% [markdown]
# - 순서가 있는 목록

# %% [markdown]
# 1. 첫 번째 목록
# 2. 두 번째 목록
# 3. 세 번째 목록

# %% [markdown]
# 1. 목록 첫 번째
#     2. 목록 두 번째
#         3. 목록 세 번째

# %% [markdown]
# ## 3. 강조
# *과 _ 사용해서 강조

# %% [markdown]
# - 이텔릭체

# %% [markdown]
# *이텔릭체* _이텔릭체_

# %% [markdown]
# - 굵은 글씨(볼드체)

# %% [markdown]
# **이텔릭체** __이텔릭체__

# %% [markdown]
# #4. 링크연결
# 자주 쓰임
#
# [이름](url) 형태로 작성

# %% [markdown]
# [네이버](https://www.naver.com/)

# %% [markdown]
# [구글](https://www.google.com/webhp?hl=ko&sa=X&ved=0ahUKEwjPncWzvamBAxXLNd4KHRSNDOsQPAgJ)

# %% [markdown]
# # 5. 이미지
# 링크와 작성법은 동일 but
#
# !가 맨앞에 추가된다는 점이 차이점

# %% [markdown]
# ![이미지](data:image/jpeg;base64,...)

# %% [markdown]
# # 6. 코드 블록

# %% [markdown]
# - 인라인 코드 (inline code)

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# `print('hi')`

# %% [markdown]
# ```python
# print('hi')
# ```

# %% [markdown]
# ```sql
# select * from table
# ```

# %% [markdown]
# #7. 인용문

# %% [markdown]
# > 멋쟁이 사자처럼 AI 개발자 취업!

# %% [markdown]
# # 8. 수평선

# %% [markdown]
# ---
